# %%
from pypsdm.analysis.concurrency import start_simultaneity_analysis
from datetime import datetime

folder_inputs = r'C:\Users\smdafeis\Documents\GitHub\simona\input\2023\20231221_test_glz\grid'
folder_glz_cases = r'C:\Users\smdafeis\Documents\GitHub\simona\input\2023\20231221_test_glz\GLZ'
folder_res = r'C:\Users\smdafeis\Documents\GitHub\simona\output\2023\20231221_test_glz\20231221_test_glz_2023-12-21_10-31-15\rawOutputData'
output_folder = r'C:\Users\smdafeis\Documents\GitHub\simona\output\2023\20231221_test_glz\20231221_test_glz_2023-12-21_10-31-15\glz'
endtime = datetime(2019,12,31)
num_mc = 15
start_simultaneity_analysis(folder_inputs, folder_glz_cases, folder_res, output_folder, endtime,num_mc)
# Out:
# C:\Users\smdafeis\AppData\Local\pypoetry\Cache\virtualenvs\pypsdm-qt54NClq-py3.11\Lib\site-packages\scipy\optimize\_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# Done for pv1_bs1_ev1_hp1_hpnew1 containing 3 elements
# C:\Users\smdafeis\AppData\Local\pypoetry\Cache\virtualenvs\pypsdm-qt54NClq-py3.11\Lib\site-packages\scipy\optimize\_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# Done for pv1_bs1_ev1_hp1_hpnew0 containing 3 elements
# C:\Users\smdafeis\AppData\Local\pypoetry\Cache\virtualenvs\pypsdm-qt54NClq-py3.11\Lib\site-packages\scipy\optimize\_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# ...
